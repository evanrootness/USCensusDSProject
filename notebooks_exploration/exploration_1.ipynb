# %%
# change current directory to the project directory
import os

# change directory
os.chdir("../")

# print current directory
os.getcwd()
# Out:
# '/Users/evanrootness/Project1/USCensusDSProject'

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import scipy.optimize as opt
import seaborn as sns

# %%
dfFinance = pd.read_csv('data/Finance.csv')
dfEducation = pd.read_csv('data/Educationv.csv')
dfIndustry = pd.read_csv('data/Industry.csv')

# %%
# test = pd.read_csv('/kaggle/input/titanic/test.csv')

# training['train_test'] = 1
# test['train_test'] = 0
# test['Survived'] = np.NaN
# all_data = pd.concat([training,test])
# all_data.columns

# %% [markdown]
# # Data Exploration

# %%
print(dfIndustry.shape, dfFinance.shape, dfEducation.shape)
# Out:
# (1311, 43) (1311, 13) (874, 5)

# %%
dfEducation['numCd'] = dfEducation['cd'].str.extract('(\d+)', expand=False).astype(int)
dfEducation['strCd'] = dfEducation['cd'].str.extract('([A-Z][A-Z])', expand=False).astype(str)

dfFinance['numCd'] = dfFinance['cd'].str.extract('(\d+)', expand=False).astype(int)
dfFinance['strCd'] = dfFinance['cd'].str.extract('([A-Z][A-Z])', expand=False).astype(str)

dfIndustry['numCd'] = dfIndustry['cd'].str.extract('(\d+)', expand=False).astype(int)
dfIndustry['strCd'] = dfIndustry['cd'].str.extract('([A-Z][A-Z])', expand=False).astype(str)

# %%
dfEducation = dfEducation.where(dfEducation['Year'] == 2021)
dfFinance = dfFinance.where(dfFinance['Year'] == 2021)
dfIndustry = dfIndustry.where(dfIndustry['Year'] == 2021)

# %%
dfEducation.dropna(axis = 0, how = 'any', inplace = True)
dfFinance.dropna(axis = 0, how = 'any', inplace = True)
dfIndustry.dropna(axis = 0, how = 'any', inplace = True)

# %%
keysEducation=dfEducation.keys()
keysFinance=dfFinance.keys()
keysIndustry=dfIndustry.keys()

# %%
all_data = pd.concat([dfEducation, dfFinance, dfIndustry], axis = 1)
# all_data.columns
all_data.describe()
# Out:
#          Year  Bachelors_degree_or_higher  high_school_or_some_degree  \
# count   437.0                  437.000000                4.370000e+02
# mean   2021.0               147891.800915                2.707819e+05
# std       0.0                82493.379197                1.132051e+05
# min    2021.0                 2872.000000                1.359300e+04
# 25%    2021.0                93616.000000                1.986190e+05
# 50%    2021.0               127207.000000                2.690800e+05
# 75%    2021.0               182977.000000                3.415510e+05
# max    2021.0               561182.000000                1.191468e+06
#
#        Less_than_high_school_graduate       numCd    Year  Less_than_$5000  \
# count                      437.000000  437.000000   437.0       437.000000
# mean                     49541.775744   10.077803  2021.0      9179.716247
# std                      31241.260932   10.606316     0.0      8897.492841
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 874 entries, 437 to 1310
# Data columns (total 67 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   Year                                                                                437 non-null    float64
#  1   cd                                                                                  437 non-null    object
#  2   Bachelors_degree_or_higher                                                          437 non-null    float64
#  3   high_school_or_some_degree                                                          437 non-null    float64
#  4   Less_than_high_school_graduate                                                      437 non-null    float64
# ...
